# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
#  YOUR CODE GOES HERE
application_df.drop(['EIN', 'NAME'], axis = 1, inplace = True)

# %%
# Determine the number of unique values in each column.
#  YOUR CODE GOES HERE
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
#  YOUR CODE GOES HERE
application_df["APPLICATION_TYPE"].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE
application_types_to_replace = ['T9', 'T13', 'T12', 'T2', 'T25', 'T14', 'T29', 'T15', 'T17']
# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
#  YOUR CODE GOES HERE
application_df["CLASSIFICATION"].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
#  YOUR CODE GOES HERE
classification_df  = application_df["CLASSIFICATION"].value_counts().loc[lambda x : x>1]
classification_df
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE
# Replace in dataframe
classifications_to_replace = list(classification_df[classification_df < 300].index)
# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# Other    34273
# C1580        1
# C1900        1
# C1820        1
# C6100        1
# C1248        1
# C2600        1
# C1370        1
# C5200        1
# C4200        1
# C2190        1
# C1236        1
# C2570        1
# C3700        1
# C2561        1
# C2500        1
# C1570        1
# C1283        1
# C2380        1
# C1732        1
# C1728        1
# C2170        1
# C4120        1
# C8210        1
# C4500        1
# C1245        1
# C2150        1
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
#  YOUR CODE GOES HERE
cols = [col for col in application_df.columns if application_df.dtypes[col] == 'object']
df_with_dummies = pd.get_dummies(application_df, columns=cols)
df_with_dummies
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# ...

# %%
# Split our preprocessed data into our features and target arrays
#  YOUR CODE GOES HERE
X  = df_with_dummies.drop(columns='IS_SUCCESSFUL', axis=1)
y = df_with_dummies['IS_SUCCESSFUL']

# Split the preprocessed data into a training and testing dataset
#  YOUR CODE GOES HERE
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
X_train
# Out:
#        STATUS  ASK_AMT  APPLICATION_TYPE_Other  APPLICATION_TYPE_T10  \
# 13532       1    14651                       0                     0
# 6087        1     5000                       0                     0
# 21879       1    17162                       0                     0
# 6193        1     5000                       0                     0
# 28999       1     5000                       0                     0
# ...       ...      ...                     ...                   ...
# 13359       1     5000                       0                     0
# 7079        1     5000                       0                     0
# 21827       1   108245                       0                     0
# 16717       1     5000                       0                     0
# 28518       1     5000                       0                     0
#
#        APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  APPLICATION_TYPE_T4  \
# ...

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
X_train_scaled[0]
# Out:
# array([ 0.01079982, -0.03243656, -0.08940766, -0.12631614, -0.17915797,
#         0.51551722, -0.21799562, -0.18519442, -0.19062721, -0.14573754,
#        -0.14587657, -0.92021435, -0.04139318,  0.92613763, -0.03118975,
#        -0.01247081, -0.01870803, -0.00623504, -0.00623504, -0.00623504,
#        -0.00623504, -0.00623504, -0.00623504,  0.        , -0.00623504,
#        -0.00623504,  0.        , -0.00623504, -0.00623504,  0.        ,
#        -0.00623504, -0.00623504, -0.00623504, -0.00623504, -0.00623504,
#        -0.00623504, -0.00623504, -0.00623504,  0.        , -0.00623504,
#        -0.00623504,  0.        , -0.00623504,  0.02858365, -0.10733765,
#        -0.06612829, -0.00881785,  0.46677307, -0.44142208, -0.64973713,
#        -0.12146379, -0.03637956,  0.67452011, -1.57494419, -0.1454591 ,
#        -0.12551965, -0.329838  , -0.08204493, -0.17053882,  2.86649057,
#        -0.06340457, -0.07450354,  0.02925687, -0.02925687])

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn = tf.keras.models.Sequential()
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 =  8
hidden_nodes_layer2 = 5
# First hidden layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 8)                 520
#
#  dense_7 (Dense)             (None, 5)                 45
#
#  dense_8 (Dense)             (None, 1)                 6
#
# ...
# Total params: 571
# Trainable params: 571
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
#  YOUR CODE GOES HERE
nn_fit = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 1s 697us/step - loss: 0.6163 - accuracy: 0.6974
# Epoch 2/100
# 804/804 [==============================] - 1s 661us/step - loss: 0.5800 - accuracy: 0.7247
# Epoch 3/100
# 804/804 [==============================] - 0s 622us/step - loss: 0.5734 - accuracy: 0.7252
# Epoch 4/100
# 804/804 [==============================] - 0s 607us/step - loss: 0.5699 - accuracy: 0.7274
# Epoch 5/100
# 804/804 [==============================] - 0s 617us/step - loss: 0.5675 - accuracy: 0.7275
# Epoch 6/100
# 804/804 [==============================] - 0s 608us/step - loss: 0.5668 - accuracy: 0.7283
# Epoch 7/100
# 804/804 [==============================] - 0s 612us/step - loss: 0.5665 - accuracy: 0.7281
# Epoch 8/100
# 804/804 [==============================] - 0s 611us/step - loss: 0.5660 - accuracy: 0.7276
# Epoch 9/100
# 804/804 [==============================] - 0s 608us/step - loss: 0.5660 - accuracy: 0.7277
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5735 - accuracy: 0.7190 - 139ms/epoch - 519us/step
# Loss: 0.5735458731651306, Accuracy: 0.7189504504203796

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
nn.save('Folder/starter_code.h5')
